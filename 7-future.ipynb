# %% [markdown]
# ## 未来计划内容

# %% [markdown]
# 本教程还将增加如下模块：

# %% [markdown]
# * Jupyter可视化
# * JupyterLab
# * JupyterHub
# * 内核配置
# * 如何安装其他kernel

# %% [markdown]
# 本教程部分内容仍不够详细，请读者见谅。我会在以后的版本中陆续完善<br>
# jupyter是一个快速迭代的项目，希望喜欢使用jupyter的朋友一起参与本教程的更新与编辑。<br>
# 谢谢！
